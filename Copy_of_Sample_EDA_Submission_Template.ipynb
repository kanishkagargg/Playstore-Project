# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkagargg/Playstore-Project/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
Play_Store_Data = pd.read_csv("Play Store Data.csv")
User_Reviews = pd.read_csv("User Reviews.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
Play_Store_Data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
User_Reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
Play_Store_Data.shape
# Out:
# (10841, 13)

# %%
User_Reviews.shape
# Out:
# (64295, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Play_Store_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
User_Reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df2 = Play_Store_Data.pivot_table(index = ['App'], aggfunc ='size')
print(df2)
# Out:
# App
# "i DT" Fútbol. Todos Somos Técnicos.                1
# +Download 4 Instagram Twitter                       1
# - Free Comics - Comic Apps                          1
# .R                                                  1
# /u/app                                              1
#                                                    ..
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                             1
# 💎 I'm rich                                          1
# 💘 WhatsLov: Smileys of love, stickers and GIF       1
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!    1
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍    1
# Length: 9660, dtype: int64

# %%
Play_Store_Data.set_index('App', inplace = True)

# %%
d1 = Play_Store_Data.loc["8 Ball Pool"]
d1
# Out:
#             Category  Rating   Reviews Size      Installs  Type Price  \
# App
# 8 Ball Pool     GAME     4.5  14198297  52M  100,000,000+  Free     0
# 8 Ball Pool     GAME     4.5  14198602  52M  100,000,000+  Free     0
# 8 Ball Pool     GAME     4.5  14200344  52M  100,000,000+  Free     0
# 8 Ball Pool     GAME     4.5  14200550  52M  100,000,000+  Free     0
# 8 Ball Pool     GAME     4.5  14201891  52M  100,000,000+  Free     0
# 8 Ball Pool     GAME     4.5  14201604  52M  100,000,000+  Free     0
# 8 Ball Pool   SPORTS     4.5  14184910  52M  100,000,000+  Free     0
#
#             Content Rating  Genres   Last Updated Current Ver   Android Ver
# App
# 8 Ball Pool       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 8 Ball Pool       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 8 Ball Pool       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# 8 Ball Pool       Everyone  Sports  July 31, 2018       4.0.0  4.0.3 and up
# ...

# %%
len(Play_Store_Data)-len(Play_Store_Data.drop_duplicates()) #duplicate rows in the Play store dataset
# Out:
# 492

# %%
len(Play_Store_Data['App'])-len(Play_Store_Data['App'].drop_duplicates()) #duplicate apps in "App" column in the Play store dataset
# Out:
# 1181

# %%
Play_Store_Data['App'].nunique() #unique values of apps in "App" column in the Play store dataset
# Out:
# 9660

# %%
len(User_Reviews)-len(User_Reviews.drop_duplicates()) #duplicate rows in the User Reviews dataset
# Out:
# 33616

# %%
len(User_Reviews['App'])-len(User_Reviews['App'].drop_duplicates()) #duplicate apps in "App" column in the User Reviews dataset
# Out:
# 63221

# %%
User_Reviews['App'].nunique()  #unique values of apps in "App" column in the User Reviews dataset
# Out:
# 1074

# %%
df3 = User_Reviews.pivot_table(index = ['App'], aggfunc ='size')
print(df3)
# Out:
# App
# 10 Best Foods for You                             200
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                   40
# 11st                                               40
# 1800 Contacts - Lens Store                         80
# 1LINE – One Line with One Touch                    40
#                                                  ...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security     40
# Hotstar                                            40
# Hotwire Hotel & Car Rental App                     40
# Housing-Real Estate & Property                     40
# Houzz Interior Design Ideas                        59
# Length: 1074, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
Play_Store_Data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
User_Reviews.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Explanation - in Play_Store_Data, there are 9660 unique values in 'App' column  i.e. 1181 dupliacte value. But there are only 483 rows that have all duplicate values in all columns. Hence, we can say that there are many Apps that appeared in the dataset with at least one different column entry. From '8 Ball Pool' multiple rows data, we can see that number of reviews varies.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
Play_Store_Data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
User_Reviews.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
Play_Store_Data.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
User_Reviews.describe(include='all')
# Out:
#                         App Translated_Review Sentiment  Sentiment_Polarity  \
# count                 64295             37427     37432        37432.000000
# unique                 1074             27994         3                 NaN
# top     Angry Birds Classic              Good  Positive                 NaN
# freq                    320               247     23998                 NaN
# mean                    NaN               NaN       NaN            0.182146
# std                     NaN               NaN       NaN            0.351301
# min                     NaN               NaN       NaN           -1.000000
# 25%                     NaN               NaN       NaN            0.000000
# 50%                     NaN               NaN       NaN            0.150000
# 75%                     NaN               NaN       NaN            0.400000
# max                     NaN               NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in Play_Store_Data.columns.tolist():
  print("No. of unique values in ",i,"is",Play_Store_Data[i].nunique(),".")
# Out:
# No. of unique values in  App is 9660 .
# No. of unique values in  Category is 34 .
# No. of unique values in  Rating is 40 .
# No. of unique values in  Reviews is 6002 .
# No. of unique values in  Size is 462 .
# No. of unique values in  Installs is 22 .
# No. of unique values in  Type is 3 .
# No. of unique values in  Price is 93 .
# No. of unique values in  Content Rating is 6 .
# No. of unique values in  Genres is 120 .
# No. of unique values in  Last Updated is 1378 .
# No. of unique values in  Current Ver is 2832 .
# No. of unique values in  Android Ver is 33 .

# %%
for i in User_Reviews.columns.tolist():
  print("No. of unique values in ",i,"is",User_Reviews[i].nunique(),".")
# Out:
# No. of unique values in  App is 1074 .
# No. of unique values in  Translated_Review is 27994 .
# No. of unique values in  Sentiment is 3 .
# No. of unique values in  Sentiment_Polarity is 5410 .
# No. of unique values in  Sentiment_Subjectivity is 4474 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
Play_Store_Data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
Play_Store_Data[Play_Store_Data['Category'] == '1.9']  #in row 10472, after analysing each column we can see that category is 1.9 which does not makes sense. And also that each and every column value must shift to its right (Then every value like size, tyoe, rating will make sense).
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
Play_Store_Data.loc[10472] = Play_Store_Data.loc[10472].shift() #all values shifted to the left. so we need to assign value of category (which is now must be app name) to app

# %%
Play_Store_Data['App'].loc[10472] = Play_Store_Data['Category'].loc[10472]
Play_Store_Data['Category'].loc[10472] = np.nan
Play_Store_Data.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              NaN
# Rating                                                1.9
# Reviews                                              19.0
# Size                                                 3.0M
# Installs                                           1,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                                NaN
# Last Updated                            February 11, 2018
# Current Ver                                        1.0.19
# Android Ver                                    4.0 and up
# Name: 10472, dtype: object

# %%
Play_Store_Data['Last Updated'] = pd.to_datetime(Play_Store_Data['Last Updated'])
Play_Store_Data['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10841, dtype: datetime64[ns]

# %%
Play_Store_Data['Type'] = Play_Store_Data['Type'].fillna('Unknown')
Play_Store_Data['Content Rating'] = Play_Store_Data['Content Rating'].fillna('Unknown')
Play_Store_Data['Current Ver'] = Play_Store_Data['Current Ver'].fillna('Z')
Play_Store_Data['Android Ver'] = Play_Store_Data['Android Ver'].fillna('Z')

User_Reviews['Sentiment_Polarity'] = User_Reviews['Sentiment_Polarity'].fillna(value= User_Reviews['Sentiment_Polarity'].mean())
User_Reviews['Sentiment_Subjectivity'] = User_Reviews['Sentiment_Subjectivity'].fillna(value= User_Reviews['Sentiment_Subjectivity'].mean())

# %%
Play_Store_Data['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4.0, nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5.0, 2.6, 3.0, 1.9, 2.5, 2.8,
#        2.7, 1.0, 2.9, 2.3, 2.2, 1.7, 2.0, 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2, '1.9'], dtype=object)

# %%
Play_Store_Data['Rating'] = Play_Store_Data['Rating'].astype('float')

# %%
Play_Store_Data['Reviews'] = Play_Store_Data['Reviews'].str.replace('3.0M','3000000')
Play_Store_Data['Reviews'] = Play_Store_Data['Reviews'].astype(float)
# Out:
# <ipython-input-11-95d13842adf9>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Play_Store_Data['Reviews'] = Play_Store_Data['Reviews'].str.replace('3.0M','3000000')

# %%
Play_Store_Data['Price'] = Play_Store_Data['Price'].str.replace('Everyone','0')
Play_Store_Data['Price'] = Play_Store_Data['Price'].str.replace('$', '')
Play_Store_Data['Price'] = Play_Store_Data['Price'].astype('float')
# Out:
# <ipython-input-12-0d007a78e1ce>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Play_Store_Data['Price'] = Play_Store_Data['Price'].str.replace('$', '')

# %%
User_Reviews['Sentiment_Polarity'] = User_Reviews['Sentiment_Polarity'].astype('float')
User_Reviews['Sentiment_Subjectivity'] = User_Reviews['Sentiment_Subjectivity'].astype('float')

# %%
Play_Store_Data['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
Play_Store_Data['Size'] = Play_Store_Data['Size'].str.replace('Varies with device','0')
Play_Store_Data['Size'] = Play_Store_Data['Size'].str.replace("M","000") # Here all MB size is coverted into a uniform kilobyte
Play_Store_Data['Size'] = Play_Store_Data['Size'].str.replace("k","")
Play_Store_Data['Size'] = Play_Store_Data['Size'].replace("1,000+",1000)
Play_Store_Data['Size'] = Play_Store_Data['Size'].astype(float)
Play_Store_Data['Size']
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        0.0
# 10840    19000.0
# Name: Size, Length: 10841, dtype: float64

# %%
Play_Store_Data['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
Play_Store_Data['Installs'] = Play_Store_Data['Installs'].str.replace(',','')
Play_Store_Data['Installs'] = Play_Store_Data['Installs'].str.replace("+","") # I will use the minimum of each ignoring the + sign (to know in which category they fall)
Play_Store_Data['Installs'] = Play_Store_Data['Installs'].str.replace("Free","0")
Play_Store_Data['Installs'] = Play_Store_Data['Installs'].astype(float)
Play_Store_Data['Installs']
# Out:
# <ipython-input-17-acb8183ee7b1>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Play_Store_Data['Installs'] = Play_Store_Data['Installs'].str.replace("+","") # I will use the minimum of each ignoring the + sign (to know in which category they fall)
# 0           10000.0
# 1          500000.0
# 2         5000000.0
# 3        50000000.0
# 4          100000.0
#             ...
# 10836        5000.0
# 10837         100.0
# 10838        1000.0
# 10839        1000.0
# 10840    10000000.0
# Name: Installs, Length: 10841, dtype: float64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 category

# %%
# Chart - 1 visualization code

sns.set(rc={'figure.figsize':(5,10)})
ax = sns.countplot(data=Play_Store_Data, y="Category", order = Play_Store_Data['Category'].value_counts().index)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2 cat & price

# %%
# Chart - 2 visualization code

cat_ins = Play_Store_Data.groupby(['Category'], as_index=False)['Price'].sum().sort_values(by='Price', ascending=False)
sns.set(rc={'figure.figsize':(70,10)})
ax = sns.barplot(x = 'Category',y= 'Price' ,data = cat_ins)


for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3 sent & app

# %%
# Chart - 3 visualization code
sent_app = User_Reviews.groupby(['Sentiment'], as_index=False)['App'].count().sort_values(by='App', ascending=False)
sns.set(rc={'figure.figsize':(10,5)})
ax = sns.barplot(x = 'Sentiment', y= 'App' ,data = sent_app)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4 install & cat

# %%
# Chart - 4 visualization code
cat_ins = Play_Store_Data.groupby(['Category'], as_index=False)['Installs'].mean().sort_values(by='Installs', ascending=False)
sns.set(rc={'figure.figsize':(70,10)})
ax = sns.barplot(x = 'Category',y= 'Installs' ,data = cat_ins)


for bars in ax.containers:
    ax.bar_label(bars)

# %%
cat_ins

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5 cat & reviews

# %%
# Chart - 5 visualization code
cat_rev = Play_Store_Data.groupby(['Category'], as_index=False)['Reviews'].mean().sort_values(by='Reviews', ascending=False)
sns.set(rc={'figure.figsize':(70,10)})
ax = sns.barplot(x = 'Category',y= 'Reviews' ,data = cat_rev)


for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6 rating histo

# %%
# Chart - 6 visualization code
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(Play_Store_Data["Rating"], bins = [0, 1, 2, 3, 4, 5])


for bars in ax.containers:
    ax.bar_label(bars)

# Show plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7 CR & inst

# %%
# Chart - 7 visualization code
cr_ins = Play_Store_Data.groupby(['Content Rating'], as_index=False)['Installs'].mean().sort_values(by='Installs', ascending=False)
sns.set(rc={'figure.figsize':(10,5)})
ax = sns.barplot(x = 'Content Rating',y= 'Installs' ,data = cr_ins)


for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8 type & ins

# %%
# Chart - 8 visualization code
type_ins = Play_Store_Data.groupby(['Type'], as_index=False)['Installs'].mean().sort_values(by='Installs', ascending=False)
sns.set(rc={'figure.figsize':(10,5)})
ax = sns.barplot(x = 'Type', y= 'Installs' ,data = type_ins)


for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9 cat & rating

# %%
# Chart - 9 visualization code
cr_ins = Play_Store_Data.groupby(['Category'], as_index=False)['Rating'].mean().sort_values(by='Rating', ascending=False)
sns.set(rc={'figure.figsize':(50, 7)})
ax = sns.barplot(x = 'Category',y= 'Rating' ,data = cr_ins)


for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10 CR + Type + price + size

# %%
# Chart - 10 visualization code
g = sns.FacetGrid(Play_Store_Data, col="Content Rating", hue="Type")
g.map(sns.scatterplot, "Size", "Price", alpha=.7)
g.add_legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11 pol, subj, senti

# %%
# Chart - 11 visualization code
sns.relplot(
    data=User_Reviews,
    x="Sentiment_Polarity", y="Sentiment_Subjectivity", hue="Sentiment"
)

# %%
import statsmodels.api as sm
g = sns.FacetGrid(User_Reviews, col="Sentiment", height=4)
g.map(sm.qqplot, "Sentiment_Polarity", "Sentiment_Subjectivity")
g.add_legend()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize = (10,9))
sns.lineplot( x = 'Last Updated', y='Installs', color='g', data = Play_Store_Data)


plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
dataplot = sns.heatmap(Play_Store_Data.corr())
# Out:
# <ipython-input-38-0913a087d417>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sns.heatmap(Play_Store_Data.corr())

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(Play_Store_Data)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
